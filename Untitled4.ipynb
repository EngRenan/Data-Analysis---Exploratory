# %% [markdown]
# <a href="https://colab.research.google.com/github/EngRenan/Data-Analysis---Exploratory/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Carregando o dataframe
df = pd.read_excel('/content/ZRPP019 (1) (1).xlsx')

# %%
df.head(25)
# Out:
#       Ordem Tipo de ordem first Tipo de ordem  Operação Centro de trabalho  \
# 0   1792311                ZSER          ZSER        60             0571PM
# 1   1792311                ZSER          ZSER        70               0583
# 2   1792311                ZSER          ZSER        90               3500
# 3   1792312                ZSER          ZSER        60             0571PM
# 4   1792312                ZSER          ZSER        70               0583
# 5   1792312                ZSER          ZSER        90               3500
# 6   1792313                ZSER          ZSER        60             0571PM
# 7   1792313                ZSER          ZSER        70               0583
# 8   1792313                ZSER          ZSER        90               3500
# 9   1904892                ZSER          ZSER        60               3508
# 10  1920777                ZSER          ZSER        70               3508
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66505 entries, 0 to 66504
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Ordem                 66505 non-null  int64
#  1   Tipo de ordem first   66505 non-null  object
#  2   Tipo de ordem         66505 non-null  object
#  3   Operação              66505 non-null  int64
#  4   Centro de trabalho    66505 non-null  object
#  5   Texto breve material  66505 non-null  object
#  6   Nº peça fabricante    59133 non-null  object
#  7   Quantidade operação   66505 non-null  int64
#  8   Fim real operação     66505 non-null  datetime64[ns]
#  9   Nova Coluna           3441 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(6)
# memory usage: 5.1+ MB

# %%
# Selecione as linhas da coluna que começam com um número
linhas_selecionadas = df[df['Texto breve material'].str.match('^\d')]
df.head(50)
# Out:
#       Ordem Tipo de ordem first Tipo de ordem  Operação Centro de trabalho  \
# 0   1792311                ZSER          ZSER        60             0571PM
# 1   1792311                ZSER          ZSER        70               0583
# 2   1792311                ZSER          ZSER        90               3500
# 3   1792312                ZSER          ZSER        60             0571PM
# 4   1792312                ZSER          ZSER        70               0583
# 5   1792312                ZSER          ZSER        90               3500
# 6   1792313                ZSER          ZSER        60             0571PM
# 7   1792313                ZSER          ZSER        70               0583
# 8   1792313                ZSER          ZSER        90               3500
# 9   1904892                ZSER          ZSER        60               3508
# 10  1920777                ZSER          ZSER        70               3508
# ...

# %%
import re

padrao = r".*?(?=/)"
df["Selecionado"] = df["Texto breve material"].apply(lambda x: re.findall(padrao, x)[0] if re.findall(padrao, x) else None)

# Selecione os números até o caractere '/'
#numeros_selecionados = linhas_selecionadas['Texto breve material'].str.extract('^(\d+)', expand=False)

# %%
# Adicione uma nova coluna ao DataFrame com os números selecionados
df['Nova Coluna'] = numeros_selecionados
df.head(2000)
# Out:
#         Ordem Tipo de ordem first Tipo de ordem  Operação Centro de trabalho  \
# 0     1792311                ZSER          ZSER        60             0571PM
# 1     1792311                ZSER          ZSER        70               0583
# 2     1792311                ZSER          ZSER        90               3500
# 3     1792312                ZSER          ZSER        60             0571PM
# 4     1792312                ZSER          ZSER        70               0583
# ...       ...                 ...           ...       ...                ...
# 1995  1909359                ZRET          ZRET       140             0571PM
# 1996  1909359                ZRET          ZRET       160               0583
# 1997  1909359                ZRET          ZRET       180               0586
# 1998  1912619                ZRET          ZRET        10               3401
# 1999  1912619                ZRET          ZRET        30               3610
#
# ...
